# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Fiorella Lucia Spatuzza**  Chemical Engineer

# %% [markdown]
# *I'm interested in data science because I like the way it helps organizations and people to make betters decisions with accurate evidence and information.*

# %% [markdown]
# ### My simply code calculates the area of a 5 cm radious circle

# %%
def area(n):
    return 3,14*(n^2)
area(5)
# Out:
# (3, 98)

# %% [markdown]
# ---
# Horizontal Rule ^
# >
# > This is blockquoted text.
# >
#
# This is [my store link](http://pignus-arg.com.ar).
